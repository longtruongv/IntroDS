# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql import SparkSession

# %%
# spark = SparkSession.builder \
#     .appName("sparkTest") \
#     .config("spark.mongodb.input.uri", "mongodb://localhost:27017/news_crawled.baomoi") \
#     .config("spark.mongodb.output.uri", "mongodb://localhost:27017/processed.baomoi") \
#     .config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.11:2.3.2') \
#     .getOrCreate()

spark = SparkSession.builder.appName("Python Spark SQL basic example").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# d:\DataScienceProj\spark\test.ipynb Cell 2 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # spark = SparkSession.builder \
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> #     .appName("sparkTest") \
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> #     .config("spark.mongodb.input.uri", "mongodb://localhost:27017/news_crawled.baomoi") \
#    (...)
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>
# ...

# %%
df = spark.read\
    .format('json')\
    .option( "uri", "mongodb://localhost:27017/news_crawled.baomoi") \
    .load()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\DataScienceProj\spark\test.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df = spark.read\
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>     .format('json')\
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>     .option( "uri", "mongodb://localhost:27017/news_crawled.baomoi") \
#       <a href='vscode-notebook-cell:/d%3A/DataScienceProj/spark/test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     .load()
#
# NameError: name 'spark' is not defined
